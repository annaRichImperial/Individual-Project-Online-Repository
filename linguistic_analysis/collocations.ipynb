# %%
from __future__ import division
import nltk
import os
import string
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import brown
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
from nltk.stem import WordNetLemmatizer
from nltk.corpus.reader.bnc import BNCCorpusReader
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder
from nltk.collocations import TrigramAssocMeasures, TrigramCollocationFinder

#GET RID OF PUNCTUATION 
#LOOK AT WOMEN 
#MOVE TO TOPIC

newcorpus = PlaintextCorpusReader('data', '.*')
files = newcorpus.fileids()
# define punctuation
punctuation = '''!()-–[]{};:'"“”\,<>’./?@#$%^&*_~'''

for f in files:
    print(f)
    bigram_measures = BigramAssocMeasures()
    trigram_measures = TrigramAssocMeasures()

    finder = BigramCollocationFinder.from_words(newcorpus.words(f))
    scored = finder.score_ngrams(bigram_measures.raw_freq)
    
    finder = TrigramCollocationFinder.from_words(newcorpus.words(f))
    scored = finder.score_ngrams(trigram_measures.raw_freq)
    
    finder.apply_word_filter(lambda w: w in punctuation)

    
    print('top 2'),
    print(sorted(finder.nbest(trigram_measures.raw_freq, 10)))
    
    common_list = [[]]
    for s in scored:
        if 'Commonwealth' in s[0]:
            print(s)
        if 'people' in s[0]:
            print(s)
# Out:
# 1952.txt
# top 2
# [('Abbey', 'will', 'hear'), ('Already', 'you', 'have'), ('As', 'he', 'used'), ('Commonwealth', 'and', 'Empire'), ('I', 'am', 'speaking'), ('I', 'want', 'to'), ('are', 'young', 'in'), ('in', 'all', 'the'), ('those', 'who', 'are'), ('who', 'are', 'young')]
# (('Commonwealth', 'and', 'Empire'), 0.0026041666666666665)
# (('British', 'Commonwealth', 'and'), 0.0013020833333333333)
# (('Commonwealth', '.', 'On'), 0.0013020833333333333)
# (('his', 'people', 'in'), 0.0013020833333333333)
# (('my', 'people', '.'), 0.0013020833333333333)
# (('now', 'my', 'people'), 0.0013020833333333333)
# (('of', 'our', 'Commonwealth'), 0.0013020833333333333)
# (('of', 'the', 'Commonwealth'), 0.0013020833333333333)
# (('our', 'Commonwealth', '.'), 0.0013020833333333333)
# (('people', '.', 'As'), 0.0013020833333333333)
# (('people', 'in', 'all'), 0.0013020833333333333)
# (('the', 'British', 'Commonwealth'), 0.0013020833333333333)
# (('the', 'Commonwealth', 'and'), 0.0013020833333333333)
# ...
