# %%
#this code works out h-point
#h-point is when you take text, rank words by decreasing frequency (of use in the text)
#h-point is when the rank equals the frequency.
#from this, it is said that those with lower ranking (highest frequencies) are likely functional words
#(e.g. grammatical purpose), and those below h-point are topical (e.g. have content/describable meaning. e.g. nouns)
#therefore, if you find a lexical/topical word at lower ranks than h-point, 
#can deduce it was "insisted on" in text (it was purposefully spoken about)

import nltk
import os
import sys
import string
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer

def hpoint(text):


    lemmatizer = WordNetLemmatizer()

    #porter = nltk.PorterStemmer()
    
    #get words (between white spaces)
    words = text.split()
        
    #strip punctuation
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in words]
    
    #strip non-alphabetics
    alpha_stripped = [word for word in stripped if word.isalpha()]
        
    #convert everything to lower case
    lower_stripped = [word.lower() for word in alpha_stripped]
    
    #lemmatize
    list_v = ([lemmatizer.lemmatize(t) for t in lower_stripped])

    #get frequency data of words
    fdist = FreqDist(list_v)
    new_list = fdist.most_common(len(fdist))

    count = 0
    
    # define punctuation
    punctuations = '''!()-–[]{};:'"“”\,,<>’../?@#$%^&*_~'''
    
    #remove punctuation (some were remaining, not sure why)
    for words in new_list:
        if words[0] in punctuations:
            print(words[0])
            new_list.remove(words)

    
    for words, nextw in zip(new_list, new_list[1:]):

        count += 1
         
        #at the point where the frequency equals rank, have reached "h-point"
        if count == words[1]:
            print('hpoint: '),
            print(count)
            #print words up to the "h-point"
            print(new_list[:count])
            break;

        #below does the same, if the h-point isn't a clean rank = frequency    
        if (count < words[1]) and (count+1 > nextw[1]):
            print('hpoint: ' ),
            alt = (((words[1]) * (count+1)) - ((nextw[1]) * count))/ (((count+1)-count) + ((words[1])-(nextw[1])))
            print (alt)
            print(new_list[:int(round(alt))])
            break;


def main():

    nltk.download('wordnet')

    file_name = sys.argv[1]
    newcorpus = PlaintextCorpusReader('data', '.*')
    files = newcorpus.fileids()

    for f in files:
        print(f)
        hpoint(newcorpus.raw(f))
        
if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\annah\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 1952.txt
# hpoint:
# 10.5
# [('and', 29), ('the', 28), ('to', 25), ('of', 23), ('i', 19), ('in', 15), ('a', 14), ('all', 14), ('my', 12), ('you', 12)]
# 1953.txt
# hpoint:
# 11.333333333333334
# [('and', 47), ('the', 42), ('of', 35), ('i', 24), ('to', 24), ('a', 20), ('that', 16), ('in', 15), ('is', 14), ('it', 13), ('all', 12)]
# 1954.txt
# hpoint:
# 9.333333333333334
# [('the', 40), ('and', 31), ('of', 25), ('in', 21), ('to', 19), ('a', 18), ('is', 13), ('we', 11), ('that', 10)]
# 1955.txt
# hpoint:
# 11
# [('the', 48), ('of', 48), ('and', 25), ('to', 24), ('a', 17), ('we', 15), ('in', 15), ('our', 13), ('all', 12), ('for', 12), ('have', 11)]
# 1956.txt
# hpoint:
# 11
# [('of', 41), ('the', 40), ('and', 31), ('to', 29), ('a', 21), ('that', 19), ('is', 15), ('all', 13), ('in', 13), ('it', 13), ('i', 11)]
# 1957.txt
# hpoint:
# 12
# [('the', 39), ('and', 39), ('to', 28), ('i', 27), ('of', 26), ('a', 17), ('that', 17), ('we', 15), ('my', 14), ('you', 14), ('in', 14), ('is', 12)]
# 1958.txt
# hpoint:
# 11
# [('and', 44), ('to', 38), ('the', 38), ('of', 32), ('a', 18), ('my', 13), ('we', 13), ('that', 12), ('you', 11), ('in', 11), ('be', 11)]
# 1959.txt
# hpoint:
# 4.5
# [('you', 7), ('to', 5), ('and', 5), ('the', 5)]
# 1960.txt
# hpoint:
# 7.5
# [('the', 32), ('of', 25), ('and', 25), ('to', 16), ('a', 13), ('in', 9), ('which', 8), ('all', 7)]
# 1961.txt
# hpoint:
# 8
# [('the', 32), ('and', 30), ('of', 21), ('to', 14), ('in', 13), ('a', 11), ('by', 9), ('is', 8)]
# 1962.txt
# hpoint:
# 9
# [('the', 42), ('of', 24), ('and', 23), ('a', 16), ('in', 13), ('to', 13), ('we', 13), ('is', 12), ('it', 9)]
# 1963.txt
# hpoint:
# 4.5
# [('the', 16), ('and', 10), ('of', 9), ('to', 5)]
# 1964.txt
# hpoint:
# 9
# [('the', 32), ('of', 26), ('and', 24), ('to', 23), ('a', 22), ('is', 21), ('in', 13), ('i', 9), ('you', 9)]
# 1965.txt
# hpoint:
# 10
# [('the', 32), ('and', 29), ('to', 19), ('of', 17), ('in', 17), ('a', 15), ('is', 13), ('we', 13), ('it', 12), ('christmas', 10)]
# 1966.txt
# hpoint:
# 8.333333333333334
# [('the', 27), ('to', 19), ('of', 19), ('and', 15), ('in', 11), ('a', 10), ('woman', 10), ('be', 9)]
# 1967.txt
# hpoint:
# 11
# [('the', 65), ('and', 47), ('of', 43), ('a', 29), ('in', 21), ('to', 21), ('i', 14), ('for', 13), ('it', 12), ('is', 12), ('have', 11)]
# 1968.txt
# hpoint:
# 8.5
# [('the', 33), ('and', 23), ('of', 19), ('to', 14), ('we', 13), ('is', 10), ('have', 10), ('in', 9)]
# 1969.txt
# hpoint:
# 6
# [('and', 16), ('the', 15), ('of', 12), ('to', 9), ('a', 8), ('all', 6)]
# 1970.txt
# hpoint:
# 10
# [('the', 35), ('of', 27), ('and', 20), ('in', 20), ('a', 17), ('to', 14), ('we', 12), ('it', 12), ('that', 11), ('is', 10)]
# 1971.txt
# hpoint:
# 8
# [('the', 21), ('and', 14), ('a', 11), ('of', 11), ('our', 11), ('for', 10), ('we', 8), ('to', 8)]
# 1972.txt
# hpoint:
# 9
# [('the', 35), ('and', 35), ('of', 24), ('to', 22), ('a', 15), ('in', 15), ('have', 10), ('we', 10), ('are', 9)]
# 1973.txt
# hpoint:
# 9
# [('the', 27), ('and', 25), ('of', 20), ('that', 11), ('i', 10), ('a', 10), ('to', 10), ('in', 10), ('are', 9)]
# 1974.txt
# hpoint:
# 9.5
# [('the', 34), ('and', 31), ('of', 30), ('in', 22), ('we', 17), ('a', 13), ('is', 12), ('have', 11), ('to', 10), ('this', 9)]
# 1975.txt
# hpoint:
# 9.5
# [('the', 29), ('of', 25), ('a', 18), ('and', 18), ('we', 13), ('are', 13), ('to', 11), ('is', 10), ('it', 10), ('our', 9)]
# 1976.txt
# hpoint:
# 9
# [('the', 38), ('and', 27), ('to', 20), ('that', 16), ('is', 15), ('a', 15), ('of', 15), ('in', 14), ('reconciliation', 9)]
# 1977.txt
# hpoint:
# 8
# [('the', 37), ('of', 17), ('and', 14), ('in', 12), ('to', 11), ('that', 10), ('a', 8), ('all', 8)]
# 1978.txt
# hpoint:
# 10
# [('the', 61), ('to', 26), ('of', 26), ('and', 24), ('in', 13), ('a', 13), ('that', 13), ('for', 12), ('future', 11), ('christmas', 10)]
# 1979.txt
# hpoint:
# 7.8
# [('the', 46), ('of', 32), ('and', 28), ('to', 25), ('child', 15), ('in', 12), ('a', 11), ('they', 7)]
# 1980.txt
# hpoint:
# 9
# [('the', 49), ('and', 38), ('in', 32), ('of', 28), ('that', 20), ('to', 19), ('a', 11), ('you', 9), ('service', 9)]
# 1981.txt
# hpoint:
# 10.666666666666666
# [('the', 50), ('of', 36), ('to', 35), ('and', 33), ('a', 23), ('in', 20), ('we', 15), ('is', 15), ('have', 14), ('courage', 12), ('people', 10)]
# 1982.txt
# hpoint:
# 10
# [('the', 90), ('of', 49), ('and', 42), ('to', 25), ('in', 24), ('a', 20), ('commonwealth', 14), ('it', 12), ('this', 12), ('is', 10)]
# 1983.txt
# hpoint:
# 9.333333333333334
# [('the', 47), ('in', 32), ('and', 32), ('of', 28), ('to', 26), ('we', 15), ('is', 11), ('i', 10), ('that', 10)]
# 1984.txt
# hpoint:
# 9
# [('the', 30), ('of', 28), ('and', 25), ('to', 18), ('a', 17), ('we', 14), ('it', 14), ('that', 11), ('in', 9)]
# 1985.txt
# hpoint:
# 11
# [('the', 44), ('to', 35), ('of', 32), ('and', 30), ('a', 29), ('for', 15), ('that', 14), ('in', 14), ('there', 13), ('are', 12), ('is', 11)]
# 1986.txt
# hpoint:
# 8.5
# [('the', 31), ('and', 28), ('to', 25), ('of', 19), ('in', 18), ('a', 17), ('is', 10), ('for', 9)]
# 1987.txt
# hpoint:
# 9
# [('of', 30), ('the', 29), ('to', 24), ('and', 21), ('a', 12), ('i', 11), ('we', 10), ('all', 9), ('are', 9)]
# 1988.txt
# hpoint:
# 11.6
# [('the', 78), ('and', 42), ('of', 37), ('in', 33), ('to', 27), ('a', 18), ('which', 17), ('year', 16), ('that', 15), ('we', 14), ('it', 14), ('christmas', 10)]
# 1989.txt
# hpoint:
# 10.5
# [('the', 60), ('to', 37), ('of', 36), ('and', 35), ('a', 21), ('in', 15), ('you', 13), ('for', 13), ('child', 11), ('our', 11)]
# 1990.txt
# hpoint:
# 9.5
# [('the', 49), ('of', 35), ('and', 30), ('to', 28), ('in', 19), ('their', 16), ('we', 14), ('that', 11), ('for', 10), ('at', 9)]
# 1991.txt
# hpoint:
# 10
# [('the', 53), ('and', 42), ('of', 40), ('to', 29), ('in', 20), ('a', 13), ('we', 13), ('that', 12), ('i', 11), ('for', 10)]
# 1992.txt
# hpoint:
# 10
# [('to', 37), ('and', 32), ('the', 28), ('of', 23), ('in', 20), ('a', 20), ('that', 13), ('this', 12), ('year', 10), ('i', 10)]
# 1993.txt
# hpoint:
# 10
# [('the', 60), ('of', 33), ('and', 23), ('to', 20), ('we', 18), ('in', 14), ('a', 12), ('it', 10), ('is', 10), ('all', 10)]
# 1994.txt
# hpoint:
# 9
# [('the', 46), ('and', 35), ('of', 34), ('in', 28), ('to', 25), ('we', 16), ('that', 14), ('a', 13), ('be', 9)]
# 1995.txt
# hpoint:
# 10
# [('the', 45), ('of', 41), ('and', 33), ('to', 26), ('a', 18), ('it', 13), ('for', 10), ('those', 10), ('who', 10), ('is', 10)]
# 1996.txt
# hpoint:
# 9.5
# [('the', 42), ('of', 31), ('and', 30), ('to', 25), ('a', 21), ('in', 17), ('i', 13), ('we', 13), ('is', 10), ('with', 9)]
# 1997.txt
# hpoint:
# 9.5
# [('the', 49), ('and', 37), ('of', 36), ('a', 25), ('to', 22), ('that', 19), ('in', 17), ('for', 10), ('we', 10), ('all', 9)]
# 1998.txt
# hpoint:
# 10.5
# [('and', 40), ('the', 33), ('of', 31), ('a', 27), ('to', 26), ('their', 15), ('is', 13), ('they', 13), ('u', 11), ('that', 11)]
# 1999.txt
# hpoint:
# 11
# [('the', 53), ('of', 35), ('and', 30), ('a', 21), ('to', 19), ('year', 14), ('in', 13), ('this', 12), ('for', 12), ('we', 11), ('i', 11)]
# 2000.txt
# hpoint:
# 7.5
# [('the', 40), ('of', 28), ('a', 24), ('and', 23), ('to', 17), ('in', 14), ('i', 8), ('this', 7)]
# 2001.txt
# hpoint:
# 10
# [('and', 33), ('to', 29), ('of', 26), ('a', 24), ('the', 23), ('in', 18), ('u', 12), ('all', 11), ('we', 11), ('this', 10)]
# 2002.txt
# hpoint:
# 9
# [('the', 38), ('to', 29), ('of', 24), ('and', 22), ('a', 18), ('i', 11), ('that', 11), ('in', 9), ('is', 9)]
# 2003.txt
# hpoint:
# 8
# [('the', 30), ('to', 29), ('and', 27), ('of', 26), ('a', 18), ('i', 14), ('this', 10), ('that', 8)]
# 2004.txt
# hpoint:
# 9.333333333333334
# [('the', 31), ('of', 21), ('a', 20), ('and', 20), ('to', 18), ('is', 14), ('for', 10), ('that', 10), ('in', 10)]
# 2005.txt
# hpoint:
# 8
# [('the', 36), ('and', 24), ('of', 21), ('in', 18), ('to', 14), ('this', 11), ('that', 8), ('is', 8)]
# 2006.txt
# hpoint:
# 9
# [('the', 42), ('to', 26), ('of', 25), ('and', 24), ('a', 18), ('that', 11), ('for', 11), ('i', 9), ('is', 9)]
# 2007.txt
# hpoint:
# 9
# [('the', 39), ('of', 28), ('and', 27), ('a', 21), ('to', 18), ('in', 15), ('who', 12), ('family', 10), ('that', 9)]
# 2008.txt
# hpoint:
# 10
# [('the', 35), ('of', 27), ('and', 26), ('to', 21), ('in', 20), ('a', 19), ('have', 11), ('for', 10), ('are', 10), ('their', 10)]
# 2009.txt
# hpoint:
# 9
# [('and', 30), ('the', 29), ('of', 19), ('to', 18), ('it', 10), ('a', 10), ('in', 10), ('is', 10), ('for', 9)]
# 2010.txt
# hpoint:
# 7.666666666666667
# [('the', 40), ('of', 38), ('and', 28), ('to', 24), ('a', 20), ('in', 13), ('all', 9), ('this', 7)]
# 2011.txt
# hpoint:
# 11
# [('the', 43), ('of', 36), ('and', 30), ('in', 23), ('a', 20), ('to', 13), ('this', 12), ('that', 12), ('it', 12), ('family', 11), ('we', 11)]
# 2012.txt
# hpoint:
# 8.5
# [('the', 43), ('of', 34), ('and', 24), ('to', 21), ('a', 17), ('in', 12), ('i', 11), ('those', 9)]
# 2013.txt
# hpoint:
# 8
# [('the', 42), ('of', 26), ('a', 22), ('and', 19), ('to', 16), ('in', 13), ('for', 10), ('we', 8)]
# 2014.txt
# hpoint:
# 8
# [('the', 46), ('of', 34), ('and', 29), ('a', 28), ('in', 22), ('to', 14), ('is', 10), ('war', 8)]
# 2015.txt
# hpoint:
# 9.5
# [('the', 40), ('of', 34), ('to', 27), ('a', 26), ('and', 16), ('that', 13), ('christmas', 11), ('in', 10), ('for', 10), ('year', 9)]
# 2016.txt
# hpoint:
# 7
# [('of', 27), ('the', 26), ('and', 23), ('a', 17), ('to', 14), ('but', 8), ('they', 7)]
# 2017.txt
# hpoint:
# 8.5
# [('the', 34), ('of', 32), ('a', 29), ('and', 23), ('to', 14), ('home', 10), ('i', 9), ('in', 9)]
# 2018.txt
# hpoint:
# 7.666666666666667
# [('the', 35), ('a', 29), ('of', 25), ('and', 17), ('in', 13), ('to', 12), ('it', 9), ('with', 7)]
